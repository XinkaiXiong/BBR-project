# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Use TimeStamp as index for Y, instead of 0,1, ... 
# Convert TimeStamp into date-time format
X = pd.read_csv('RedQueueDisc-PacketsInDeviceQueue.csv', header = None)
Y = pd.read_csv('RedQueueDisc-PacketsInQueueDisc.csv', header = None)
#timeIndex=pd.to_datetime(X[0], unit='s')
#timeIndex=pd.to_datetime(Y['TimeStamp'], unit='s')
X.index=X[0]
Y.index = Y[0]

# Generate a figure with one subplot 
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(16, 8))

# Produce the plots for specified features sets
x = X[1].plot(color='r')
y = Y[1].plot(color = 'b')

axes.grid(True)

# Customizing plot (changing font size, labels)
font_size = 20
plt.title('BBR vs. BBR (buffer: 100 packets)', fontsize=font_size)
plt.xlabel('Time (s)', fontsize=font_size)
plt.ylabel('Queue (packets)', fontsize=font_size)
plt.legend(('Pkts_in_DeviceQ','Pkts_in_Qdisc'), loc = 'upper right', shadow=False, fancybox=True, fontsize=font_size-2)
plt.tick_params(axis='both', which='major', labelsize=font_size-2)
plt.tick_params(axis='both', which='minor', labelsize=font_size-4)
plt.tight_layout()
plt.savefig("Queue.png")
plt.show()
